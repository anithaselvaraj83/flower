# %% [markdown]
# <a href="https://colab.research.google.com/github/anithaselvaraj83/flower/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/anithaselvaraj83/flower.git
# Out:
# fatal: destination path 'flower' already exists and is not an empty directory.

# %%
image = cv2.imread("flower/images5.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 183 275 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 1 17 10

# %%
plt.imshow(image)
